# %%
# Conexão com o Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Comando para configurar um caminho no drive
# !ln -s /content/drive/MyDrive/Colab\ Notebooks/PGC/TL /TL

# %%
# Consulta dos arquivos no diratório
# !ls /TL/Gray/datasets
# Out:
# dataset1perm96train24valid  dataset2perm96train24valid
# dataset1type96train24valid  dataset2type96train24valid

# %%
# Cópia dos arquivos para realizar o treinamento
# !cp -r /TL/Gray/datasets/dataset1type96train24valid ./
# !cp -r /TL/Gray/datasets/dataset2type96train24valid ./
# !cp -r /TL/Gray/datasets/dataset1perm96train24valid/ ./
# !cp -r /TL/Gray/datasets/dataset2perm96train24valid ./
# !cp /TL/yolov8_cfg.yaml ./yolov8_cfg.yaml

# %%
# Código para renomear os diretórios
# !mv dataset1type96train24valid dataset
# !mv dataset2type96train24valid dataset
# !mv dataset1perm96train24valid dataset
# !mv dataset2perm96train24valid dataset

# %%
# > /dev/null para omitir o download da biblioteca
# !pip install ultralytics > /dev/null

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Editando o arquivo yaml
# %%writefile yolov8_cfg.yaml
# path: '/content/dataset'
# train: 'train/'
# val: 'valid/'

# nc: 2
# names: ['Triangulo', 'Circulo']

# %%
import cv2
import matplotlib.pyplot as plt
import os
from PIL import Image
from google.colab.patches import cv2_imshow

# %%
path = '/content/yolov8_cfg.yaml'

# %%
# !yolo task=detect mode=train data={path} epochs=10

# %%
# nmodel = YOLO('yolov8n.yaml')
# smodel = YOLO('yolov8s.yaml')
mmodel = YOLO('yolov8m.yaml')
# lmodel = YOLO('yolov8l.yaml')

# %%
# Treinamento por TL
# sres = smodel.train(data=path, epochs=100, imgsz = 640, name='yolov8_smodel')
# mres = mmodel.train(data=path, epochs=100, imgsz = 640, name='yolov8_mmodel')

# Continuação por TL
# !yolo task=detect mode=train model='/content/runs/detect/yolov8_mmodel/weights/last.pt' data={path} epochs=100
# !yolo task=detect mode=train model='/content/runs1800eperm2/detect/train/weights/last.pt' data={path} epochs=100

# %% [markdown]
# Dataset Homogeneo 1 objeto de cada classe

# %%
from datetime import datetime, timedelta
time1 = datetime.now()

# %%
# !yolo task=detect mode=train model=yolov8m.pt data={path} epochs=100 imgsz=640 save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
time2 = datetime.now()
print((time2 - time1))
# Out:
# 0:09:43.760095

# %%
# Codigo para configurar UTF-8
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# Renomeando o diretório para a quantidade de épocas treinadas 100e
# Para o datataset do conjunto potência com dois objetos de cada classe perm2
# !mv runs runs100epoch1type

# %%
# Copiando o diretório para a nuvem
# !cp -r runs100epoch1type /TL/Gray

# %%
# !rm -r dataset
# !rm -r runs100epoch1type

# %%
# Cópia dos arquivos para realizar o treinamento
# !cp -r /TL/Gray/datasets/dataset1type96train24valid ./
# !cp -r /TL/Gray/datasets/dataset2type96train24valid ./
# !cp -r /TL/Gray/datasets/dataset1perm96train24valid/ ./
# !cp -r /TL/Gray/datasets/dataset2perm96train24valid ./

# %%
# Código para renomear os diretórios
# !mv dataset1type96train24valid dataset
# !mv dataset2type96train24valid dataset
# !mv dataset1perm96train24valid dataset
# !mv dataset2perm96train24valid dataset

# %% [markdown]
# Dataset Homogêneo com 2 objetos de cada classe

# %%
time1 = datetime.now()
# !yolo task=detect mode=train model=yolov8m.pt data={path} epochs=100 imgsz=640 save=True
time2 = datetime.now()
print((time2 - time1))
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 307MB/s]
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !mv runs runs100epoch2type

# %%
# !cp -r runs100epoch2type /TL/Gray

# %%
# !rm -r dataset

# %% [markdown]
# Potência 1

# %%
# Cópia dos arquivos para realizar o treinamento
# !cp -r /TL/Gray/datasets/dataset1type96train24valid ./
# !cp -r /TL/Gray/datasets/dataset2type96train24valid ./
# !cp -r /TL/Gray/datasets/dataset1perm96train24valid/ ./
# !cp -r /TL/Gray/datasets/dataset2perm96train24valid ./

# %%
# Código para renomear os diretórios
# !mv dataset1type96train24valid dataset
# !mv dataset2type96train24valid dataset
# !mv dataset1perm96train24valid dataset
# !mv dataset2perm96train24valid dataset

# %%
time1 = datetime.now()
# !yolo task=detect mode=train model=yolov8m.pt data={path} epochs=100 imgsz=640 save=True
time2 = datetime.now()
print((time2 - time1))
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !mv runs runs100epoch1perm

# %%
# !cp -r runs100epoch1perm /TL/Gray

# %%
# !rm -r dataset

# %%
# Cópia dos arquivos para realizar o treinamento
# !cp -r /TL/Gray/datasets/dataset1type96train24valid ./
# !cp -r /TL/Gray/datasets/dataset2type96train24valid ./
# !cp -r /TL/Gray/datasets/dataset1perm96train24valid/ ./
# !cp -r /TL/Gray/datasets/dataset2perm96train24valid ./

# %%
# Código para renomear os diretórios
# !mv dataset1type96train24valid dataset
# !mv dataset2type96train24valid dataset
# !mv dataset1perm96train24valid dataset
# !mv dataset2perm96train24valid dataset

# %%
time1 = datetime.now()
# !yolo task=detect mode=train model=yolov8m.pt data={path} epochs=100 imgsz=640 save=True
time2 = datetime.now()
print((time2 - time1))
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !mv runs runs100epoch2perm

# %%
# !cp -r runs100epoch2perm /TL/Gray

# %%
# !cp -r /TL/Color/dataset2type96train24valid/ ./

# %%
# !mv dataset2type96train24valid dataset

# %%
# !cp -r runs /TL/Color/

# %%
# !ls /TL/Gray
# !ls /TL/Color
# Out:
# dataset2type96train24valid

# %% [markdown]
# Validação

# %%
def draw(img):
  fig = plt.gcf()
  fig.set_size_inches(16,10)
  plt.axis('off')
  plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
dir_predicoes = 'runs/detect/predict/'
caminhos = [os.path.join(dir_predicoes, f) for f in os.listdir(dir_predicoes)]

for caminho_imagem in caminhos:
  imagem = cv2.imread(caminho_imagem)

  draw(imagem)

# %%
#Validação
# !yolo task=detect mode=val model='runs/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics YOLOv8.0.238 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid.cache... 120 images, 0 backgrounds, 0 corrupt: 100% 120/120 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 8/8 [00:06<00:00,  1.19it/s]
#                    all        120        270      0.717      0.832      0.855       0.55
#              Triangulo        120        135      0.748      0.856      0.865      0.566
#                Circulo        120        135      0.686      0.807      0.845      0.535
# Speed: 2.4ms preprocess, 23.6ms inference, 0.0ms loss, 6.7ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !cp -r runs150eperm2 /TL/Gray/

# %%
# !unzip weights-20231109T212416Z-001.zip
# Out:
# Archive:  weights-20231109T212416Z-001.zip
#   inflating: weights/last.pt
#   inflating: weights/best.pt

# %%
# !cp -r /TL/Gray/100e2type800train200valid ./
