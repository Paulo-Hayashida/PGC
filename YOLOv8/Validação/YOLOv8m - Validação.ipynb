# %%
# Conexão com o Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Comando para configurar um caminho no drive
# !ln -s /content/drive/MyDrive/Colab\ Notebooks/PGC/TL /TL

# %%
# Consulta dos arquivos no diratório
# !ls /TL/Gray/
# Out:
# datasets  runs100epoch1perm  runs100epoch2perm	runs551eperm2
# models	  runs100epoch1type  runs100epoch2type	yolov8_yolo_tutorial.py

# %%
# Cópia dos datasets
# !cp -r /TL/Gray/datasets/dataset1type96train24valid ./
# !cp -r /TL/Gray/datasets/dataset2type96train24valid ./
# !cp -r /TL/Gray/datasets/dataset1perm96train24valid ./
# !cp -r /TL/Gray/datasets/dataset2perm96train24valid ./

# %%
# Cópia dos arquivos para realizar o treinamento
# !cp /TL/yolov8_cfg.yaml ./yolov8_cfg.yaml

# %%
# Cópia dos modelos
# !cp -r /TL/Gray/runs100epoch1type ./
# !cp -r /TL/Gray/runs100epoch2type ./
# !cp -r /TL/Gray/runs100epoch1perm ./
# !cp -r /TL/Gray/runs100epoch2perm ./

# %%
# > /dev/null para omitir o download da biblioteca
# !pip install ultralytics > /dev/null

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import cv2
import matplotlib.pyplot as plt
import os
from PIL import Image
from google.colab.patches import cv2_imshow

# %%
path = '/content/yolov8_cfg.yaml'

# %%
# Codigo para configurar UTF-8
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# Código para renomear os diretórios
# !rm -r dataset
# !mv dataset1type96train24valid dataset
# !mv dataset2type96train24valid dataset
# !mv dataset1perm96train24valid dataset
# !mv dataset2perm96train24valid dataset

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 23.2MB/s]
# val: Scanning /content/dataset/valid... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<00:00, 559.36it/s]
# val: New cache created: /content/dataset/valid.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:04<00:00,  2.41s/it]
#                    all         24         48          1          1      0.995      0.995
#              Triangulo         24         24          1          1      0.995      0.995
#                Circulo         24         24          1          1      0.995      0.995
# Speed: 15.8ms preprocess, 27.9ms inference, 0.0ms loss, 45.4ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid.cache... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.13it/s]
#                    all         24         48      0.998          1      0.995      0.995
#              Triangulo         24         24          1          1      0.995      0.995
#                Circulo         24         24      0.997          1      0.995      0.995
# Speed: 5.0ms preprocess, 23.7ms inference, 0.0ms loss, 28.1ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid.cache... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.18it/s]
#                    all         24         48          1          1      0.995      0.995
#              Triangulo         24         24          1          1      0.995      0.995
#                Circulo         24         24          1          1      0.995      0.995
# Speed: 0.4ms preprocess, 28.4ms inference, 0.0ms loss, 25.5ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval3
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid.cache... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.19it/s]
#                    all         24         48          1          1      0.995      0.995
#              Triangulo         24         24          1          1      0.995      0.995
#                Circulo         24         24          1          1      0.995      0.995
# Speed: 0.4ms preprocess, 29.5ms inference, 0.0ms loss, 25.1ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval4
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model='/content/runs/detect/yolov8_mmodel/weights/best.pt' source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs/detect/yolov8_mmodel/weights/best.pt' conf=0.50 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/train1type800train200valid/weights/best.pt' source='/content/dataset/valid' save=True

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00000.jpg: 640x640 1 Triangulo, 1 Circulo, 37.0ms
# image 2/24 /content/dataset/valid/00001.jpg: 640x640 1 Triangulo, 1 Circulo, 37.0ms
# image 3/24 /content/dataset/valid/00002.jpg: 640x640 1 Triangulo, 1 Circulo, 37.0ms
# image 4/24 /content/dataset/valid/00003.jpg: 640x640 1 Triangulo, 1 Circulo, 36.9ms
# image 5/24 /content/dataset/valid/00004.jpg: 640x640 1 Triangulo, 1 Circulo, 37.0ms
# image 6/24 /content/dataset/valid/00005.jpg: 640x640 1 Triangulo, 1 Circulo, 25.0ms
# image 7/24 /content/dataset/valid/00006.jpg: 640x640 1 Triangulo, 1 Circulo, 21.1ms
# image 8/24 /content/dataset/valid/00007.jpg: 640x640 1 Triangulo, 1 Circulo, 21.2ms
# image 9/24 /content/dataset/valid/00008.jpg: 640x640 1 Triangulo, 1 Circulo, 21.2ms
# ...

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00000.jpg: 640x640 1 Triangulo, 1 Circulo, 36.9ms
# image 2/24 /content/dataset/valid/00001.jpg: 640x640 1 Triangulo, 1 Circulo, 37.0ms
# image 3/24 /content/dataset/valid/00002.jpg: 640x640 1 Triangulo, 1 Circulo, 37.0ms
# image 4/24 /content/dataset/valid/00003.jpg: 640x640 1 Triangulo, 1 Circulo, 36.9ms
# image 5/24 /content/dataset/valid/00004.jpg: 640x640 1 Triangulo, 1 Circulo, 27.5ms
# image 6/24 /content/dataset/valid/00005.jpg: 640x640 1 Triangulo, 1 Circulo, 27.3ms
# image 7/24 /content/dataset/valid/00006.jpg: 640x640 1 Triangulo, 1 Circulo, 27.2ms
# image 8/24 /content/dataset/valid/00007.jpg: 640x640 1 Triangulo, 1 Circulo, 27.2ms
# image 9/24 /content/dataset/valid/00008.jpg: 640x640 1 Triangulo, 1 Circulo, 27.2ms
# ...

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00000.jpg: 640x640 1 Triangulo, 1 Circulo, 37.0ms
# image 2/24 /content/dataset/valid/00001.jpg: 640x640 1 Triangulo, 1 Circulo, 37.0ms
# image 3/24 /content/dataset/valid/00002.jpg: 640x640 1 Triangulo, 1 Circulo, 36.9ms
# image 4/24 /content/dataset/valid/00003.jpg: 640x640 1 Triangulo, 1 Circulo, 34.5ms
# image 5/24 /content/dataset/valid/00004.jpg: 640x640 1 Triangulo, 1 Circulo, 31.5ms
# image 6/24 /content/dataset/valid/00005.jpg: 640x640 1 Triangulo, 1 Circulo, 31.4ms
# image 7/24 /content/dataset/valid/00006.jpg: 640x640 1 Triangulo, 1 Circulo, 31.5ms
# image 8/24 /content/dataset/valid/00007.jpg: 640x640 1 Triangulo, 1 Circulo, 31.4ms
# image 9/24 /content/dataset/valid/00008.jpg: 640x640 1 Triangulo, 1 Circulo, 30.7ms
# ...

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00000.jpg: 640x640 1 Triangulo, 1 Circulo, 36.9ms
# image 2/24 /content/dataset/valid/00001.jpg: 640x640 1 Triangulo, 1 Circulo, 37.1ms
# image 3/24 /content/dataset/valid/00002.jpg: 640x640 1 Triangulo, 1 Circulo, 36.9ms
# image 4/24 /content/dataset/valid/00003.jpg: 640x640 1 Triangulo, 1 Circulo, 37.0ms
# image 5/24 /content/dataset/valid/00004.jpg: 640x640 1 Triangulo, 1 Circulo, 36.9ms
# image 6/24 /content/dataset/valid/00005.jpg: 640x640 1 Triangulo, 1 Circulo, 36.9ms
# image 7/24 /content/dataset/valid/00006.jpg: 640x640 1 Triangulo, 1 Circulo, 24.0ms
# image 8/24 /content/dataset/valid/00007.jpg: 640x640 1 Triangulo, 1 Circulo, 20.1ms
# image 9/24 /content/dataset/valid/00008.jpg: 640x640 1 Triangulo, 1 Circulo, 20.1ms
# ...

# %%
# !mv runs 1type120valid

# %%
# !cp -r 1type120valid /TL/Gray

# %%
# Código para renomear os diretórios
# !rm -r dataset
# !mv dataset1type96train24valid dataset
# !mv dataset2type96train24valid dataset
# !mv dataset1perm96train24valid dataset
# !mv dataset2perm96train24valid dataset

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<00:00, 1516.47it/s]
# val: New cache created: /content/dataset/valid.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.11it/s]
#                    all         24         96      0.999          1      0.995      0.994
#              Triangulo         24         48      0.999          1      0.995      0.995
#                Circulo         24         48          1          1      0.995      0.993
# Speed: 0.3ms preprocess, 27.9ms inference, 0.0ms loss, 24.4ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid.cache... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.12it/s]
#                    all         24         96      0.999          1      0.995      0.993
#              Triangulo         24         48          1          1      0.995      0.995
#                Circulo         24         48      0.998          1      0.995      0.992
# Speed: 0.4ms preprocess, 28.0ms inference, 0.0ms loss, 25.2ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid.cache... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.16it/s]
#                    all         24         96          1          1      0.995      0.994
#              Triangulo         24         48          1          1      0.995      0.994
#                Circulo         24         48          1          1      0.995      0.994
# Speed: 0.2ms preprocess, 28.2ms inference, 0.0ms loss, 22.2ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval3
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid.cache... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.06s/it]
#                    all         24         96          1          1      0.995      0.995
#              Triangulo         24         48          1          1      0.995      0.995
#                Circulo         24         48          1          1      0.995      0.994
# Speed: 7.1ms preprocess, 24.9ms inference, 0.0ms loss, 41.6ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval4
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00000.jpg: 640x640 2 Triangulos, 2 Circulos, 37.0ms
# image 2/24 /content/dataset/valid/00001.jpg: 640x640 2 Triangulos, 2 Circulos, 37.0ms
# image 3/24 /content/dataset/valid/00002.jpg: 640x640 2 Triangulos, 2 Circulos, 36.9ms
# image 4/24 /content/dataset/valid/00003.jpg: 640x640 2 Triangulos, 2 Circulos, 36.9ms
# image 5/24 /content/dataset/valid/00004.jpg: 640x640 2 Triangulos, 2 Circulos, 36.9ms
# image 6/24 /content/dataset/valid/00005.jpg: 640x640 2 Triangulos, 2 Circulos, 36.9ms
# image 7/24 /content/dataset/valid/00006.jpg: 640x640 2 Triangulos, 2 Circulos, 36.9ms
# image 8/24 /content/dataset/valid/00007.jpg: 640x640 2 Triangulos, 2 Circulos, 35.5ms
# image 9/24 /content/dataset/valid/00008.jpg: 640x640 2 Triangulos, 2 Circulos, 20.2ms
# ...

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00000.jpg: 640x640 2 Triangulos, 2 Circulos, 37.0ms
# image 2/24 /content/dataset/valid/00001.jpg: 640x640 2 Triangulos, 2 Circulos, 37.1ms
# image 3/24 /content/dataset/valid/00002.jpg: 640x640 2 Triangulos, 2 Circulos, 36.9ms
# image 4/24 /content/dataset/valid/00003.jpg: 640x640 2 Triangulos, 2 Circulos, 36.9ms
# image 5/24 /content/dataset/valid/00004.jpg: 640x640 2 Triangulos, 2 Circulos, 36.9ms
# image 6/24 /content/dataset/valid/00005.jpg: 640x640 2 Triangulos, 2 Circulos, 29.3ms
# image 7/24 /content/dataset/valid/00006.jpg: 640x640 2 Triangulos, 2 Circulos, 20.5ms
# image 8/24 /content/dataset/valid/00007.jpg: 640x640 2 Triangulos, 2 Circulos, 20.5ms
# image 9/24 /content/dataset/valid/00008.jpg: 640x640 2 Triangulos, 2 Circulos, 20.5ms
# ...

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00000.jpg: 640x640 2 Triangulos, 2 Circulos, 37.0ms
# image 2/24 /content/dataset/valid/00001.jpg: 640x640 2 Triangulos, 2 Circulos, 37.0ms
# image 3/24 /content/dataset/valid/00002.jpg: 640x640 2 Triangulos, 2 Circulos, 36.9ms
# image 4/24 /content/dataset/valid/00003.jpg: 640x640 2 Triangulos, 2 Circulos, 37.0ms
# image 5/24 /content/dataset/valid/00004.jpg: 640x640 2 Triangulos, 2 Circulos, 36.9ms
# image 6/24 /content/dataset/valid/00005.jpg: 640x640 2 Triangulos, 2 Circulos, 36.9ms
# image 7/24 /content/dataset/valid/00006.jpg: 640x640 2 Triangulos, 2 Circulos, 35.8ms
# image 8/24 /content/dataset/valid/00007.jpg: 640x640 2 Triangulos, 2 Circulos, 19.7ms
# image 9/24 /content/dataset/valid/00008.jpg: 640x640 2 Triangulos, 2 Circulos, 19.8ms
# ...

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00000.jpg: 640x640 2 Triangulos, 2 Circulos, 36.9ms
# image 2/24 /content/dataset/valid/00001.jpg: 640x640 2 Triangulos, 2 Circulos, 37.0ms
# image 3/24 /content/dataset/valid/00002.jpg: 640x640 2 Triangulos, 2 Circulos, 37.0ms
# image 4/24 /content/dataset/valid/00003.jpg: 640x640 2 Triangulos, 2 Circulos, 36.9ms
# image 5/24 /content/dataset/valid/00004.jpg: 640x640 2 Triangulos, 2 Circulos, 37.0ms
# image 6/24 /content/dataset/valid/00005.jpg: 640x640 2 Triangulos, 2 Circulos, 34.3ms
# image 7/24 /content/dataset/valid/00006.jpg: 640x640 2 Triangulos, 2 Circulos, 19.8ms
# image 8/24 /content/dataset/valid/00007.jpg: 640x640 2 Triangulos, 2 Circulos, 19.7ms
# image 9/24 /content/dataset/valid/00008.jpg: 640x640 2 Triangulos, 2 Circulos, 19.8ms
# ...

# %%
# !mv runs 2type120valid

# %%
# !cp -r 2type120valid /TL/Gray

# %%
# Código para renomear os diretórios
# !rm -r dataset
# !mv dataset1type96train24valid dataset
# !mv dataset2type96train24valid dataset
# !mv dataset1perm96train24valid dataset
# !mv dataset2perm96train24valid dataset

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<00:00, 1695.75it/s]
# val: New cache created: /content/dataset/valid.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.10s/it]
#                    all         24         32          1          1      0.995      0.993
#              Triangulo         16         16          1          1      0.995      0.995
#                Circulo         16         16          1          1      0.995      0.991
# Speed: 5.7ms preprocess, 28.3ms inference, 0.0ms loss, 42.7ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid.cache... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.28it/s]
#                    all         24         32      0.998          1      0.995      0.993
#              Triangulo         16         16          1          1      0.995      0.995
#                Circulo         16         16      0.996          1      0.995      0.992
# Speed: 0.3ms preprocess, 28.4ms inference, 0.0ms loss, 23.3ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid.cache... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.25it/s]
#                    all         24         32          1          1      0.995      0.993
#              Triangulo         16         16          1          1      0.995      0.995
#                Circulo         16         16          1          1      0.995      0.991
# Speed: 0.3ms preprocess, 28.5ms inference, 0.0ms loss, 24.5ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval3
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid.cache... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.20it/s]
#                    all         24         32          1          1      0.995      0.995
#              Triangulo         16         16          1          1      0.995      0.995
#                Circulo         16         16          1          1      0.995      0.995
# Speed: 0.3ms preprocess, 29.2ms inference, 0.0ms loss, 27.6ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval4
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00001.jpg: 640x640 1 Circulo, 37.0ms
# image 2/24 /content/dataset/valid/00002.jpg: 640x640 1 Circulo, 37.0ms
# image 3/24 /content/dataset/valid/00003.jpg: 640x640 1 Circulo, 36.9ms
# image 4/24 /content/dataset/valid/00004.jpg: 640x640 1 Circulo, 37.0ms
# image 5/24 /content/dataset/valid/00005.jpg: 640x640 1 Circulo, 28.0ms
# image 6/24 /content/dataset/valid/00006.jpg: 640x640 1 Circulo, 27.6ms
# image 7/24 /content/dataset/valid/00007.jpg: 640x640 1 Circulo, 27.7ms
# image 8/24 /content/dataset/valid/00008.jpg: 640x640 1 Circulo, 27.6ms
# image 9/24 /content/dataset/valid/00009.jpg: 640x640 1 Triangulo, 27.6ms
# image 10/24 /content/dataset/valid/00010.jpg: 640x640 1 Triangulo, 27.6ms
# image 11/24 /content/dataset/valid/00011.jpg: 640x640 1 Triangulo, 20.6ms
# ...

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00001.jpg: 640x640 1 Circulo, 37.0ms
# image 2/24 /content/dataset/valid/00002.jpg: 640x640 1 Circulo, 37.1ms
# image 3/24 /content/dataset/valid/00003.jpg: 640x640 1 Circulo, 36.9ms
# image 4/24 /content/dataset/valid/00004.jpg: 640x640 1 Circulo, 36.9ms
# image 5/24 /content/dataset/valid/00005.jpg: 640x640 1 Circulo, 36.9ms
# image 6/24 /content/dataset/valid/00006.jpg: 640x640 1 Circulo, 36.9ms
# image 7/24 /content/dataset/valid/00007.jpg: 640x640 1 Circulo, 34.6ms
# image 8/24 /content/dataset/valid/00008.jpg: 640x640 1 Circulo, 19.9ms
# image 9/24 /content/dataset/valid/00009.jpg: 640x640 1 Triangulo, 19.2ms
# image 10/24 /content/dataset/valid/00010.jpg: 640x640 1 Triangulo, 19.5ms
# image 11/24 /content/dataset/valid/00011.jpg: 640x640 1 Triangulo, 19.3ms
# ...

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00001.jpg: 640x640 1 Circulo, 36.9ms
# image 2/24 /content/dataset/valid/00002.jpg: 640x640 1 Circulo, 37.0ms
# image 3/24 /content/dataset/valid/00003.jpg: 640x640 1 Circulo, 36.9ms
# image 4/24 /content/dataset/valid/00004.jpg: 640x640 1 Circulo, 37.0ms
# image 5/24 /content/dataset/valid/00005.jpg: 640x640 1 Circulo, 36.2ms
# image 6/24 /content/dataset/valid/00006.jpg: 640x640 1 Circulo, 22.9ms
# image 7/24 /content/dataset/valid/00007.jpg: 640x640 1 Circulo, 22.9ms
# image 8/24 /content/dataset/valid/00008.jpg: 640x640 1 Circulo, 22.9ms
# image 9/24 /content/dataset/valid/00009.jpg: 640x640 1 Triangulo, 22.6ms
# image 10/24 /content/dataset/valid/00010.jpg: 640x640 1 Triangulo, 22.4ms
# image 11/24 /content/dataset/valid/00011.jpg: 640x640 1 Triangulo, 22.4ms
# ...

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00001.jpg: 640x640 1 Circulo, 37.0ms
# image 2/24 /content/dataset/valid/00002.jpg: 640x640 1 Circulo, 37.0ms
# image 3/24 /content/dataset/valid/00003.jpg: 640x640 1 Circulo, 37.0ms
# image 4/24 /content/dataset/valid/00004.jpg: 640x640 1 Circulo, 35.8ms
# image 5/24 /content/dataset/valid/00005.jpg: 640x640 1 Circulo, 29.9ms
# image 6/24 /content/dataset/valid/00006.jpg: 640x640 1 Circulo, 29.9ms
# image 7/24 /content/dataset/valid/00007.jpg: 640x640 1 Circulo, 29.9ms
# image 8/24 /content/dataset/valid/00008.jpg: 640x640 1 Circulo, 29.9ms
# image 9/24 /content/dataset/valid/00009.jpg: 640x640 1 Triangulo, 29.9ms
# image 10/24 /content/dataset/valid/00010.jpg: 640x640 1 Triangulo, 23.7ms
# image 11/24 /content/dataset/valid/00011.jpg: 640x640 1 Triangulo, 19.4ms
# ...

# %%
# !mv runs 1perm120valid

# %%
# !cp -r 1perm120valid /TL/Gray

# %%
# Código para renomear os diretórios
# !rm -r dataset
# !mv dataset1type96train24valid dataset
# !mv dataset2type96train24valid dataset
# !mv dataset1perm96train24valid dataset
# !mv dataset2perm96train24valid dataset

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<00:00, 1738.36it/s]
# val: New cache created: /content/dataset/valid.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.08it/s]
#                    all         24         54      0.999          1      0.995      0.995
#              Triangulo         18         27      0.998          1      0.995      0.995
#                Circulo         18         27          1          1      0.995      0.995
# Speed: 5.2ms preprocess, 23.9ms inference, 0.0ms loss, 29.4ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid.cache... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.25it/s]
#                    all         24         54      0.999          1      0.995      0.995
#              Triangulo         18         27          1          1      0.995      0.995
#                Circulo         18         27      0.997          1      0.995      0.995
# Speed: 0.3ms preprocess, 27.6ms inference, 0.0ms loss, 26.5ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid.cache... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.05s/it]
#                    all         24         54      0.999          1      0.995      0.995
#              Triangulo         18         27      0.998          1      0.995      0.995
#                Circulo         18         27          1          1      0.995      0.995
# Speed: 6.5ms preprocess, 24.0ms inference, 0.0ms loss, 43.1ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval3
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#Validação
# !yolo task=detect mode=val model='runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid.cache... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:01<00:00,  1.01it/s]
#                    all         24         54          1          1      0.995      0.995
#              Triangulo         18         27          1          1      0.995      0.995
#                Circulo         18         27          1          1      0.995      0.995
# Speed: 5.5ms preprocess, 25.6ms inference, 0.0ms loss, 33.4ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval4
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00001.jpg: 640x640 1 Circulo, 37.0ms
# image 2/24 /content/dataset/valid/00002.jpg: 640x640 1 Circulo, 37.0ms
# image 3/24 /content/dataset/valid/00003.jpg: 640x640 1 Circulo, 36.9ms
# image 4/24 /content/dataset/valid/00004.jpg: 640x640 2 Circulos, 37.0ms
# image 5/24 /content/dataset/valid/00005.jpg: 640x640 2 Circulos, 36.9ms
# image 6/24 /content/dataset/valid/00006.jpg: 640x640 2 Circulos, 37.0ms
# image 7/24 /content/dataset/valid/00007.jpg: 640x640 1 Triangulo, 21.7ms
# image 8/24 /content/dataset/valid/00008.jpg: 640x640 1 Triangulo, 20.1ms
# image 9/24 /content/dataset/valid/00009.jpg: 640x640 1 Triangulo, 20.1ms
# image 10/24 /content/dataset/valid/00010.jpg: 640x640 1 Triangulo, 1 Circulo, 20.1ms
# ...

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 797, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/models/yolo/model.py", line 23, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 145, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 285, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 910, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
# ...

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00001.jpg: 640x640 1 Circulo, 37.0ms
# image 2/24 /content/dataset/valid/00002.jpg: 640x640 1 Circulo, 37.1ms
# image 3/24 /content/dataset/valid/00003.jpg: 640x640 1 Circulo, 37.0ms
# image 4/24 /content/dataset/valid/00004.jpg: 640x640 2 Circulos, 36.3ms
# image 5/24 /content/dataset/valid/00005.jpg: 640x640 2 Circulos, 36.2ms
# image 6/24 /content/dataset/valid/00006.jpg: 640x640 2 Circulos, 36.2ms
# image 7/24 /content/dataset/valid/00007.jpg: 640x640 1 Triangulo, 36.2ms
# image 8/24 /content/dataset/valid/00008.jpg: 640x640 1 Triangulo, 34.7ms
# image 9/24 /content/dataset/valid/00009.jpg: 640x640 1 Triangulo, 19.5ms
# image 10/24 /content/dataset/valid/00010.jpg: 640x640 1 Triangulo, 1 Circulo, 19.5ms
# ...

# %%
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.5 source='/content/dataset/valid' save=True
# Out:
# Ultralytics 8.3.21 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00001.jpg: 640x640 1 Circulo, 37.0ms
# image 2/24 /content/dataset/valid/00002.jpg: 640x640 1 Circulo, 37.1ms
# image 3/24 /content/dataset/valid/00003.jpg: 640x640 1 Circulo, 37.0ms
# image 4/24 /content/dataset/valid/00004.jpg: 640x640 2 Circulos, 37.0ms
# image 5/24 /content/dataset/valid/00005.jpg: 640x640 2 Circulos, 31.8ms
# image 6/24 /content/dataset/valid/00006.jpg: 640x640 2 Circulos, 24.7ms
# image 7/24 /content/dataset/valid/00007.jpg: 640x640 1 Triangulo, 24.7ms
# image 8/24 /content/dataset/valid/00008.jpg: 640x640 1 Triangulo, 24.6ms
# image 9/24 /content/dataset/valid/00009.jpg: 640x640 1 Triangulo, 24.4ms
# image 10/24 /content/dataset/valid/00010.jpg: 640x640 1 Triangulo, 1 Circulo, 24.4ms
# ...

# %%
# !mv runs 2perm120valid

# %%
# !cp -r 2perm120valid /TL/Gray
