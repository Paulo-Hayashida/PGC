# %%
# Conexão com o Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Comando para configurar um caminho no drive
# !ln -s /content/drive/MyDrive/Colab\ Notebooks/PGC/TL /TL

# %%
# Consulta dos arquivos no diratório
# !ls /TL/Gray/
# Out:
# datasets  models  validations  yolov8_yolo_tutorial.py

# %%
# Cópia dos datasets
# !cp -r /TL/Gray/datasets/dataset1type96train24valid ./
# !cp -r /TL/Gray/datasets/dataset2type96train24valid ./
# !cp -r /TL/Gray/datasets/dataset1perm96train24valid ./
# !cp -r /TL/Gray/datasets/dataset2perm96train24valid ./
# Out:
# ^C
# ^C

# %%
# Cópia do modelo
# !cp -r /TL/Color/runs ./

# %%
# Cópia dos arquivos para realizar o treinamento
# !cp /TL/yolov8_cfg.yaml ./yolov8_cfg.yaml

# %%
# > /dev/null para omitir o download da biblioteca
# !pip install ultralytics > /dev/null

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import cv2
import matplotlib.pyplot as plt
import os
from PIL import Image
from google.colab.patches import cv2_imshow

# %%
path = '/content/yolov8_cfg.yaml'

# %%
# Codigo para configurar UTF-8
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# Código para renomear os diretórios
# !rm -r dataset
# !mv dataset2type96train24valid dataset
# !mv 2perm600dataset dataset

# %%
def draw(img):
  fig = plt.gcf()
  fig.set_size_inches(16,10)
  plt.axis('off')
  plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
# !yolo task=detect mode=predict model='/content/runs/detect/yolov8_mmodel/weights/best.pt' source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/runs/detect/yolov8_mmodel/weights/best.pt' conf=0.50 source='/content/dataset/valid' save=True
# !yolo task=detect mode=predict model='/content/train1type800train200valid/weights/best.pt' source='/content/dataset/valid' save=True

# %%
# !yolo task=detect mode=val model='/content/runs100epoch1type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='/content/runs100epoch2type/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='/content/runs100epoch1perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# !yolo task=detect mode=val model='/content/runs100epoch2perm/detect/train/weights/best.pt' name=yolov8_mmodel_eval data=yolov8_cfg.yaml
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/valid... 24 images, 0 backgrounds, 0 corrupt: 100% 24/24 [00:00<00:00, 1598.29it/s]
# val: New cache created: /content/dataset/valid.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.04s/it]
#                    all         24         96   0.000375     0.0104   0.000193   0.000135
#              Triangulo         24         48    0.00075     0.0208   0.000386    0.00027
#                Circulo         24         48          0          0          0          0
# Speed: 9.7ms preprocess, 24.3ms inference, 0.0ms loss, 36.3ms postprocess per image
# Results saved to runs/detect/yolov8_mmodel_eval
# 💡 Learn more at https://docs.ultralytics.com/modes/val
# ...

# %%
# !yolo task=detect mode=predict model='/content/runs/detect/train/weights/best.pt' conf = 0.8 source='/content/dataset1type96train24valid/valid' save=True
# !yolo task=detect mode=predict model='/content/runs/detect/train/weights/best.pt' conf = 0.8 source='/content/dataset2type96train24valid/valid' save=True
# !yolo task=detect mode=predict model='/content/runs/detect/train/weights/best.pt' conf = 0.8 source='/content/dataset1perm96train24valid/valid' save=True
# !yolo task=detect mode=predict model='/content/runs/detect/train/weights/best.pt' conf = 0.8 source='/content/dataset2perm96train24valid/valid' save=True
# Out:
# /bin/bash: line 1: yolo: command not found
# /bin/bash: line 1: yolo: command not found
# /bin/bash: line 1: yolo: command not found
# /bin/bash: line 1: yolo: command not found

# %%
dir_predicoes = 'runs/detect/predict/'
caminhos = [os.path.join(dir_predicoes, f) for f in os.listdir(dir_predicoes)]

for caminho_imagem in caminhos:
  imagem = cv2.imread(caminho_imagem)

  draw(imagem)

# %%
dir_predicoes = 'runs/detect/predict2/'
caminhos = [os.path.join(dir_predicoes, f) for f in os.listdir(dir_predicoes)]

for caminho_imagem in caminhos:
  imagem = cv2.imread(caminho_imagem)

  draw(imagem)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
dir_predicoes = 'runs/detect/predict3/'
caminhos = [os.path.join(dir_predicoes, f) for f in os.listdir(dir_predicoes)]

for caminho_imagem in caminhos:
  imagem = cv2.imread(caminho_imagem)

  draw(imagem)

# %%
dir_predicoes = 'runs/detect/predict4/'
caminhos = [os.path.join(dir_predicoes, f) for f in os.listdir(dir_predicoes)]

for caminho_imagem in caminhos:
  imagem = cv2.imread(caminho_imagem)

  draw(imagem)

# %%
# !ls /TL/Color
# Out:
# dataset2type96train24valid  runs

# %%
# !cp -r /TL/Gray/models/runs100epoch1type ./
# !cp -r /TL/Gray/models/runs100epoch2type ./
# !cp -r /TL/Gray/models/runs100epoch1perm ./
# !cp -r /TL/Gray/models/runs100epoch2perm ./

# %%
# !cp -r /TL/Color/dataset2type96train24valid ./

# %%
# !mv dataset2type96train24valid dataset

# %%
print('1type')
# !yolo task=detect mode=predict model='/content/runs100epoch1type/detect/train/weights/best.pt' conf = 0.8 source='/content/dataset/valid' save=True
print('2type')
# !yolo task=detect mode=predict model='/content/runs100epoch2type/detect/train/weights/best.pt' conf = 0.8 source='/content/dataset/valid' save=True
print('1perm')
# !yolo task=detect mode=predict model='/content/runs100epoch1perm/detect/train/weights/best.pt' conf = 0.8 source='/content/dataset/valid' save=True
print('2perm')
# !yolo task=detect mode=predict model='/content/runs100epoch2perm/detect/train/weights/best.pt' conf = 0.8 source='/content/dataset/valid' save=True
# Out:
# 1type
# Ultralytics 8.3.38 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/24 /content/dataset/valid/00000.jpg: 640x640 (no detections), 37.0ms
# image 2/24 /content/dataset/valid/00001.jpg: 640x640 (no detections), 37.0ms
# image 3/24 /content/dataset/valid/00002.jpg: 640x640 (no detections), 36.9ms
# image 4/24 /content/dataset/valid/00003.jpg: 640x640 (no detections), 37.0ms
# image 5/24 /content/dataset/valid/00004.jpg: 640x640 (no detections), 24.8ms
# image 6/24 /content/dataset/valid/00005.jpg: 640x640 (no detections), 24.7ms
# image 7/24 /content/dataset/valid/00006.jpg: 640x640 (no detections), 24.7ms
# image 8/24 /content/dataset/valid/00007.jpg: 640x640 (no detections), 24.7ms
# image 9/24 /content/dataset/valid/00008.jpg: 640x640 (no detections), 24.7ms
# image 10/24 /content/dataset/valid/00009.jpg: 640x640 (no detections), 21.2ms
# ...
